# %%
import requests
from bs4 import BeautifulSoup
import json
import re
# import module
import geopy
from geopy.geocoders import Nominatim

# %%
cities = {'Aalen' ,
'Bad Mergentheim',
'Baden-Baden',
'Bruchsal',
'Esslingen',
'Freiburg im Breisgau',
'Freudenstadt',
'Friedrichshafen',
'Göppingen',
'Hechingen',
'Heidelberg',
'Heilbronn',
'Karlsruhe',
'Konstanz',
'Ludwigsburg',
'Mannheim',
'Offenburg',
'Pforzheim',
'Ravensburg',
'Reutlingen',
'Schwäbisch Gmünd',
'Schwäbisch Hall',
'Stuttgart',
'Tübingen',
'Ulm',
'Amberg',
'Ansbach',
'Aschaffenburg',
'Augsburg',
'Bad Reichenhall',
'Bamberg',
'Bayreuth',
'Berchtesgaden',
'Coburg',
'Dachau',
'Deggendorf',
'Dinkelsbühl',
'Donauwörth',
'Erlangen',
'Freising',
'Fürth',
'Füssen',
'Garmisch-Partenkirchen',
'Ingolstadt',
'Kempten',
'Landshut',
'Lindau',
'Memmingen',
'Mittenwald',
'Munich',
'Nördlingen',
'Nürnberg',
'Passau',
'Regensburg',
'Rothenburg ob der Tauber',
'Würzburg',
'Berlin',
'Brandenburg',
'Cottbus',
'Eberswalde',
'Frankfurt an der Oder',
'Potsdam',
'Schwedt',
'Bremen',
'Bremerhaven',
'Hamburg',
'Bad Homburg',
'Darmstadt',
'Frankfurt am Main',
'Fulda',
'Giessen',
'Hanau',
'Kassel',
'Lorsch',
'Marburg',
'Offenbach',
'Rüdesheim',
'Wiesbaden',
'Bad Gandersheim',
'Bad Harzburg',
'Braunschweig',
'Celle',
'Cuxhaven',
'Delmenhorst',
'Emden',
'Goslar',
'Göttingen',
'Hameln',
'Hannover',
'Helmstedt',
'Hildesheim',
'Lüneburg',
'Oldenburg',
'Osnabrück',
'Salzgitter',
'Stade',
'Wilhelmshaven',
'Wolfsburg',
'Greifswald',
'Güstrow',
'Neubrandenburg',
'Peenemünde',
'Rostock',
'Schwerin',
'Stralsund',
'Wismar',
'Aachen',
'Arnsberg',
'Bad Godesberg',
'Bergisch Gladbach',
'Bielefeld',
'Bocholt',
'Bochum',
'Bonn',
'Bottrop',
'Brühl',
'Castrop-Rauxel',
'Cologne',
'Detmold',
'Dorsten',
'Dortmund',
'Duisburg',
'Düren',
'Düsseldorf',
'Essen',
'Gelsenkirchen',
'Gladbeck',
'Gütersloh',
'Hagen',
'Hamm',
'Herne',
'Hürth',
'Iserlohn',
'Jülich',
'Kleve',
'Königswinter',
'Krefeld',
'Leverkusen',
'Lüdenscheid',
'Lünen',
'Marl',
'Minden',
'Moers',
'Mönchengladbach',
'Mülheim an der Ruhr',
'Münster',
'Neuss',
'Paderborn',
'Recklinghausen',
'Remscheid',
'Rheine',
'Siegen',
'Soest',
'Solingen',
'Wesel',
'Witten',
'Wuppertal',
'Bad Kreuznach',
'Bingen',
'Boppard',
'Frankenthal',
'Kaiserslautern',
'Koblenz',
'Landau',
'Ludwigshafen',
'Mainz',
'Neustadt an der Weinstrasse',
'Speyer',
'Trier',
'Worms',
'Homburg',
'Reinheim',
'Saarbrücken',
'Saarlouis',
'Altenburg',
'Annaberg-Buchholz',
'Bautzen',
'Chemnitz',
'Dresden',
'Freiberg',
'Görlitz',
'Hoyerswerda',
'Leipzig',
'Meissen',
'Torgau',
'Zittau',
'Zwickau',
'Bernburg',
'Dessau',
'Eisleben',
'Halberstadt',
'Halle',
'Köthen',
'Merseburg',
'Naumburg',
'Quedlinburg',
'Stendal',
'Wernigerode',
'Wittenberg',
'Büsum',
'Eutin',
'Flensburg',
'Glückstadt',
'Kiel',
'Lübeck',
'Rendsburg',
'Schleswig',
'Arnstadt',
'Eisenach',
'Erfurt',
'Gera',
'Gotha',
'Jena',
'Meiningen',
'Mühlhausen',
'Nordhausen',
'Suhl',
'Weimar'}

# %%
cities
# Out:
# {'Aachen',
#  'Aalen',
#  'Altenburg',
#  'Amberg',
#  'Annaberg-Buchholz',
#  'Ansbach',
#  'Arnsberg',
#  'Arnstadt',
#  'Aschaffenburg',
#  'Augsburg',
#  'Bad Gandersheim',
#  'Bad Godesberg',
#  'Bad Harzburg',
#  'Bad Homburg',
#  'Bad Kreuznach',
#  'Bad Mergentheim',
#  'Bad Reichenhall',
#  'Baden-Baden',
#  'Bamberg',
#  'Bautzen',
#  'Bayreuth',
#  'Berchtesgaden',
#  'Bergisch Gladbach',
#  'Berlin',
#  'Bernburg',
#  'Bielefeld',
#  'Bingen',
#  'Bocholt',
#  'Bochum',
#  'Bonn',
#  'Boppard',
#  'Bottrop',
#  'Brandenburg',
#  'Braunschweig',
#  'Bremen',
#  'Bremerhaven',
#  'Bruchsal',
#  'Brühl',
#  'Büsum',
#  'Castrop-Rauxel',
#  'Celle',
#  'Chemnitz',
#  'Coburg',
#  'Cologne',
#  'Cottbus',
#  'Cuxhaven',
#  'Dachau',
#  'Darmstadt',
#  'Deggendorf',
#  'Delmenhorst',
#  'Dessau',
#  'Detmold',
#  'Dinkelsbühl',
#  'Donauwörth',
#  'Dorsten',
#  'Dortmund',
#  'Dresden',
#  'Duisburg',
#  'Düren',
#  'Düsseldorf',
#  'Eberswalde',
#  'Eisenach',
#  'Eisleben',
# ...

# %% [markdown]
# # we test

# %%
'Bonn' in cities
# Out:
# True

# %%
'kairouan' in cities 
#yekdhbu..
# Out:
# False

# %%
'Berlin' in cities
# Out:
# True

# %%
url='https://www.bechtle.com/impressum'
page = requests.get(url)
txt=page.text
soup = BeautifulSoup(page.content,'html.parser')

# %%
soup
# Out:
#  <!DOCTYPE html>
#
# <html class="neo-html" lang="de" xml:lang="de">
# <head>
# <script src="/.resources/bechtle-ui/webresources/js/lazyload.js"></script> <script> Defer.dom('.neojs-lazy', 50, 'neo-lazy--show'); </script><meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <title>Impressum</title>
# <meta content="Impressum" name="description">
# <meta content="Impressum" name="keywords"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="website" property="og:type"/>
# <meta content="Impressum" property="og:title"/>
# <meta content="https://www.bechtle.com/impressum" property="og:url"/>
# <meta content="https://www.bechtle.com/dam/jcr:0fa10535-77f8-49a9-9ebe-163794516fe7/Impresum.jpg" property="og:image"/>
# <meta content="913" property="og:image:width"/>
# <meta content="429" property="og:image:height"/>
# ...

# %%
text_format = soup.get_text()

# %%
text_format
# Out:
# ' \n\n\n \n\n\n\nImpressum\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSuchezurückDealsHardwarezurückHardware - ÜbersichtMobile ComputingzurückMobile Computing - ÜbersichtNotebooksMobile WorkstationsMobile Thin ClientsTabletsSmartphones & MobiltelefoneWearablesGarantien & Service Mobile ComputingZubehör Mobile ComputingErsatzteile Mobile ComputingKommunikationzurückKommunikation - ÜbersichtKonferenzsystemeVoIP TelefonieISDN & analoge TelefoneHeadsetsWebcamsGarantien & Service KommunikationZubehör KommunikationIT-InfrastrukturzurückIT-Infrastruktur - ÜbersichtServerStorageUSV-SystemeNetzwerkSecurityRacksGarantien & Service IT-InfrastrukturZubehör IT-InfrastrukturErsatzteile IT-InfrastrukturComputingzurückComputing - ÜbersichtPCsWorkstationsThin ClientsAll-in-One PCsKassensystemeGarantien & Service ComputingZubehör ComputingErsatzteile ComputingPeripheriezurückPeripherie - ÜbersichtMonitorePublic DisplaysTV-GeräteProjek
# ...

# %%
#joins iterbales as strings with seperator
" ".join(soup.strings)

for script in soup(["script", "style"]):
    script.decompose()
    strips = list(soup.stripped_strings)
print(strips)
# Out:
# ['Impressum', 'Suche', 'zurück', 'Deals', 'Hardware', 'zurück', 'Hardware', '-', 'Übersicht', 'Mobile Computing', 'zurück', 'Mobile Computing', '-', 'Übersicht', 'Notebooks', 'Mobile Workstations', 'Mobile Thin Clients', 'Tablets', 'Smartphones & Mobiltelefone', 'Wearables', 'Garantien & Service Mobile Computing', 'Zubehör Mobile Computing', 'Ersatzteile Mobile Computing', 'Kommunikation', 'zurück', 'Kommunikation', '-', 'Übersicht', 'Konferenzsysteme', 'VoIP Telefonie', 'ISDN & analoge Telefone', 'Headsets', 'Webcams', 'Garantien & Service Kommunikation', 'Zubehör Kommunikation', 'IT-Infrastruktur', 'zurück', 'IT-Infrastruktur', '-', 'Übersicht', 'Server', 'Storage', 'USV-Systeme', 'Netzwerk', 'Security', 'Racks', 'Garantien & Service IT-Infrastruktur', 'Zubehör IT-Infrastruktur', 'Ersatzteile IT-Infrastruktur', 'Computing', 'zurück', 'Computing', '-', 'Übersicht', 'PCs', 'Workstations', 'Thin Clients', 'All-in-One PCs', 'Kassensysteme', 'Garantien & Service Computing', 'Zubehör Com
# ...

# %%
strips
# Out:
# ['Impressum',
#  'Suche',
#  'zurück',
#  'Deals',
#  'Hardware',
#  'zurück',
#  'Hardware',
#  '-',
#  'Übersicht',
#  'Mobile Computing',
#  'zurück',
#  'Mobile Computing',
#  '-',
#  'Übersicht',
#  'Notebooks',
#  'Mobile Workstations',
#  'Mobile Thin Clients',
#  'Tablets',
#  'Smartphones & Mobiltelefone',
#  'Wearables',
#  'Garantien & Service Mobile Computing',
#  'Zubehör Mobile Computing',
#  'Ersatzteile Mobile Computing',
#  'Kommunikation',
#  'zurück',
#  'Kommunikation',
#  '-',
#  'Übersicht',
#  'Konferenzsysteme',
#  'VoIP Telefonie',
#  'ISDN & analoge Telefone',
#  'Headsets',
#  'Webcams',
#  'Garantien & Service Kommunikation',
#  'Zubehör Kommunikation',
#  'IT-Infrastruktur',
#  'zurück',
#  'IT-Infrastruktur',
#  '-',
#  'Übersicht',
#  'Server',
#  'Storage',
#  'USV-Systeme',
#  'Netzwerk',
#  'Security',
#  'Racks',
#  'Garantien & Service IT-Infrastruktur',
#  'Zubehör IT-Infrastruktur',
#  'Ersatzteile IT-Infrastruktur',
#  'Computing',
#  'zurück',
# ...

# %%
strings = ['Impressum.',
'Anbieter:',
'Bechtle AG',
'',
'Bechtle Platz 1',
'',
'74172 Neckarsulm',
'',
'E-Mail:',
'kontakt@bechtle.com',
'',
' ',
'',
'Telefon:',
'+ 49 7132 981-0',
'',
' ',
'',
'Vorstand:',
'Dr. Thomas Olemotz (Vors.)',
'',
'Michael Guschlbauer',
'',
'Jürgen Schäfer',
'',
'Vorsitzender des Aufsichtsrates:',
'Klaus Winkler',
'',
'HRB-Nr. (beim Amtsgericht Stuttgart):',
'108581',
'',
'USt-IdNr.:',
'DE143849458',
'',
'Verantwortlich für journalistisch-redaktionellen Inhalt im Sinne von § 55 Abs. 2 RStV ist Dr. Thomas Olemotz, Anschrift siehe Anbieter.']

# %%
strings
# Out:
# ['Impressum.',
#  'Anbieter:',
#  'Bechtle AG',
#  '',
#  'Bechtle Platz 1',
#  '',
#  '74172 Neckarsulm',
#  '',
#  'E-Mail:',
#  'kontakt@bechtle.com',
#  '',
#  ' ',
#  '',
#  'Telefon:',
#  '+ 49 7132 981-0',
#  '',
#  ' ',
#  '',
#  'Vorstand:',
#  'Dr. Thomas Olemotz (Vors.)',
#  '',
#  'Michael Guschlbauer',
#  '',
#  'Jürgen Schäfer',
#  '',
#  'Vorsitzender des Aufsichtsrates:',
#  'Klaus Winkler',
#  '',
#  'HRB-Nr. (beim Amtsgericht Stuttgart):',
#  '108581',
#  '',
#  'USt-IdNr.:',
#  'DE143849458',
#  '',
#  'Verantwortlich für journalistisch-redaktionellen Inhalt im Sinne von § 55 Abs. 2 RStV ist Dr. Thomas Olemotz, Anschrift siehe Anbieter.']

# %%
with open(r"C:\Users\Njoura\Desktop\web scraping\de cities.json") as f:
    data = json.load(f)

# %%
data
# Out:
# [{'city': 'Berlin',
#   'lat': '52.5167',
#   'lng': '13.3833',
#   'country': 'Germany',
#   'iso2': 'DE',
#   'admin_name': 'Berlin',
#   'capital': 'primary',
#   'population': '3644826',
#   'population_proper': '3644826'},
#  {'city': 'Hamburg',
#   'lat': '53.5500',
#   'lng': '10.0000',
#   'country': 'Germany',
#   'iso2': 'DE',
#   'admin_name': 'Hamburg',
#   'capital': 'admin',
#   'population': '1841179',
#   'population_proper': '1841179'},
#  {'city': 'Munich',
#   'lat': '48.1372',
#   'lng': '11.5755',
#   'country': 'Germany',
#   'iso2': 'DE',
#   'admin_name': 'Bavaria',
#   'capital': 'admin',
#   'population': '1471508',
#   'population_proper': '1471508'},
#  {'city': 'Cologne',
#   'lat': '50.9422',
#   'lng': '6.9578',
#   'country': 'Germany',
#   'iso2': 'DE',
#   'admin_name': 'North Rhine-Westphalia',
#   'capital': '',
#   'population': '1085664',
#   'population_proper': '1085664'},
#  {'city': 'Frankfurt',
#   'lat': '50.1136',
#   'lng': '8.6797',
# ...

# %%
# initialize Nominatim API 
geolocator = Nominatim(user_agent="geoapiExercises")

# %% [markdown]
# the precision of the address depends on the cities and on other variables maybe...

# %%
place = "Kairouan"
location = geolocator.geocode(place)
print(location)
# Out:
# القيروان, القبلية الجنوبية, معتمدية القيروان الجنوبية, ولاية القيروان, 3172, تونس

# %%
data = location.raw
print(data)
# Out:
# {'place_id': 635359, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 287543904, 'boundingbox': ['35.5110101', '35.8310101', '9.94062', '10.26062'], 'lat': '35.6710101', 'lon': '10.10062', 'display_name': 'القيروان, القبلية الجنوبية, معتمدية القيروان الجنوبية, ولاية القيروان, 3172, تونس', 'class': 'place', 'type': 'city', 'importance': 0.5224190948365158, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_city.p.20.png'}

# %%
place_2 = "Berlin"
location_2 = geolocator.geocode(place_2)
print(location_2)
##
place_3 = "Duisburg"
location_3 = geolocator.geocode(place_3)
print(location_3)
# Out:
# Berlin, Deutschland
# Duisburg, Nordrhein-Westfalen, 47051, Deutschland

# %%
data_2 = location_2.raw
print(data_2)
data_3 = location_3.raw
print(data_3)
# Out:
# {'place_id': 285001329, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 62422, 'boundingbox': ['52.3382448', '52.6755087', '13.088345', '13.7611609'], 'lat': '52.5170365', 'lon': '13.3888599', 'display_name': 'Berlin, Deutschland', 'class': 'boundary', 'type': 'administrative', 'importance': 0.8975390282491362, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}
# {'place_id': 366035, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 240055326, 'boundingbox': ['51.274999', '51.594999', '6.599562', '6.919562'], 'lat': '51.434999', 'lon': '6.759562', 'display_name': 'Duisburg, Nordrhein-Westfalen, 47051, Deutschland', 'class': 'place', 'type': 'city', 'importance': 0.7175443549284533, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_city.p.20.png'}

# %% [markdown]
# #we only need the 'display_name' key

# %%
data_2["display_name"]
# Out:
# 'Berlin, Deutschland'

# %% [markdown]
# FINAL TESTING WITH Bechtle ADDRESS

# %%
Bechtle_place='bechtle platz 1'
#this is another problem because I needed to translate the address to the local language(we can think of a library that can translate all languages to english,but then maybe we need them in german..)
#long comment ik xD
Bechtle_location = geolocator.geocode(Bechtle_place)
print(Bechtle_location)
# Out:
# Bechtle AG, 1, Bechtle Platz, Trendpark Süd, Neckarsulm, Verwaltungsgemeinschaft Neckarsulm, Landkreis Heilbronn, Baden-Württemberg, 74172, Deutschland

# %%
# Make a regular expression for validating an Email

regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
 
# Define a function for validating an Email
 
def check(email):
 
    # pass the regular expression and the string into the fullmatch() method
    if(re.fullmatch(regex, email)):
        print(email)
 
    else:
        print("Invalid Email")
 
 





# # Driver Code
# if __name__ == '__main__':
 
#     # Enter the email
#     email = "ankitrai326@gmail.com"
 
#     # calling run function
#     check(email)
 
#     email = "my.ownsite@our-earth.org"
#     check(email)
 
#     email = "ankitrai326.com"
#     check(email)

# %%
for element in strings:
    if(re.fullmatch(regex, element)):
        print(element)
# Out:
# kontakt@bechtle.com

# %%
E_mail=check(email)

# %% [markdown]
# #At this point 'E_mail' is the key that we gonna enter to the dictionary and 'company name is the value(address that we gonna look for)

# %%
company_name='njoura@python.com'
E_mail=check(company_name)
# Out:
# njoura@python.com

# %%
regex_phone=r'\b \b'
(?x)          # Free spacing mode on and start of string
 (?:           # A container group:
   (\+49|0049|\+\(49\)|\(\+49\))? [ ()\/-]*  
   # German: country code
   (?(1)|0)1(?:5[12579]|6[023489]|7[0-9])    
   # trunk prefix and company code
 )
 [ ()\/-]*   
 # zero or more spaces, parens, / and -
 \d(?:[ \/-]*\d){6,7}
  # a digit and then six or seven occurrences of space, / or - and a digit
 \s* 
 # zero or more whites
$ # end of string
# Out:
#   File "C:\Users\Njoura\AppData\Local\Temp/ipykernel_18332/3423679717.py", line 1
#     (?x)          # Free spacing mode on and start of string
#      ^
# SyntaxError: invalid syntax
