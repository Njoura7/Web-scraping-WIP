# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
url='https://www.bechtle.com/impressum'

# %%
scraped_url=requests.get(url)
soup=BeautifulSoup(scraped_url.content,'html.parser')
body=soup.find('body').text
body=body.replace(u'\xa0',u'')
# html=html.replace(u'\n',u' ')
body_list=body.split("\n")

# %%
body_list
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %% [markdown]
# #email with reg ex!!

# %%
# Make a regular expression for validating an Email

email_regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
 
# Define a function for validating an Email
 
def check_email(email):

    # pass the regular expression and the string into the fullmatch() method

    if(re.search(email_regex, email)):
        print(email)

# %%
for add_element in body_list:
  check_email(add_element)
# Out:
# kontakt@bechtle.com

# %% [markdown]
# ZIP code with regEx

# %%
zip_regex= r'^0*(106[7-9]|10[7-9][0-9]|1[1-9][0-9]{2}|[2-9][0-9]{3}|[1-8][0-9]{4}|9[0-8][0-9]{3}|99[0-8][0-9]{2}|999[0-8][0-9]|9999[0-8])$'
def check_zipCode(zip):
   if(re.search(zip_regex, zip)):
       print (zip)

# %%
# to create a list of lists (each string will be divided into a list of strings)
listOfLists=[]
for string in body_list:
      string_to_list=string.split(" ")
      listOfLists.append(string_to_list)

# %%
listOfLists
# Out:
# [[''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['', ''],
#  [''],
#  [''],
#  [''],
#  ['Contact'],
#  ['', ''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['Sign', 'in'],
#  ['Register'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['', ''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['Search', 'for:'],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['', ''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['', ''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['Contact'],
#  ['', ''],
#  [''],
#  ['Sign', 'in'],
#  ['Register'],
#  [''],
#  [''],
#  ['', ''],
#  [''],
#  [''],
#  ['', ''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['Impressum', ''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
# ...

# %%
for add_element in body_list:
  check_email(add_element)

# %%
# looking for the numeric strings in each list
def check_numeric(lists):
    for list in listOfLists:
          for string in list:
            if string.isnumeric() and(len(string)>=4 ):
              print(string)
              # verify the regEx of the zip code
                #  check_zipCode(string)

# %%
check_numeric(listOfLists)
# Out:
# 406375

# %%
regex_phone= r"/(\(?([\d \-\)\–\+\/\(]+){6,}\)?([ .\-–\/]?)([\d]+))/"
def reg_phone(phone):
  if(re.search(regex_phone, phone)):
    print(phone)

# %%
reg_phone(+4971329810)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16212/2241375903.py in <module>
# ----> 1 reg_phone(+4971329810)
#
# ~\AppData\Local\Temp/ipykernel_16212/2936234997.py in reg_phone(phone)
#       1 regex_phone= r"/(\(?([\d \-\)\–\+\/\(]+){6,}\)?([ .\-–\/]?)([\d]+))/"
#       2 def reg_phone(phone):
# ----> 3   if(re.search(regex_phone, phone)):
#       4     print(phone)
#       5
#
# c:\Users\Njoura\anaconda3\lib\re.py in search(pattern, string, flags)
#     199     """Scan through string looking for a match to the pattern, returning
#     200     a Match object, or None if no match was found."""
# --> 201     return _compile(pattern, flags).search(string)
#     202
#     203 def sub(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
for list in listOfLists:
  for string in list:
    reg_phone(string)

# %%
regex_id = r'\b[0-9]{6}\b'
def regID(id):
  if(re.search(regex_phone, id)):
    print(id)

# %%
regID('123465')
